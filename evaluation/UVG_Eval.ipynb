# %%
# !pip install tensorflow-gpu==1.15
# Out:
# ...
#      |████████████████████████████████| 411.5MB 42kB/s
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/keras-applications/
# ...
#      |████████████████████████████████| 51kB 6.5MB/s
# ...
#      |████████████████████████████████| 512kB 43.3MB/s
# ...
#      |████████████████████████████████| 3.8MB 38.3MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7542 sha256=7e4adb421eac8736d6f778c0313ec309b0d63e87d1adc7f02cd4c90499687fca
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.3.0 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.3.0 has requirement tensorboard<3,>=2.3.0, but you'll have tensorboard 1.15.0 which is incompatible.
# ...

# %%
# !pip install tensorflow-compression
# Out:
# ...
#      |████████████████████████████████| 122kB 5.2MB/s
# ...

# %%
# %cd /content/drive/My Drive/Video_Compression_Using_Deep_Neural_Network/JCT-VC
# Out:
# /content/drive/My Drive/Video_Compression_Using_Deep_Neural_Network/JCT-VC

# %% [markdown]
# # Test on UVG Datasets

# %% [markdown]
# **Crop to required size** <br/>
# sh crop.sh infile outfile inWidth inHeight requiredWidth requiredHeight

# %%
# !sh crop.sh UVG/Beauty_1920x1080_120fps_420_8bit_YUV.yuv  UVG_cropped/Beauty.yuv 1920 1080 1920 1072
# Out:
# frame=  600 fps= 45 q=-0.0 Lsize= 1809000kB time=00:00:24.00 bitrate=617472.0kbits/s speed=1.82x
# video:1809000kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%

# %%
# !sh crop.sh UVG/Bosphorus_1920x1080_120fps_420_8bit_YUV.yuv  UVG_cropped/Bosphorus.yuv 1920 1080 1920 1072
# Out:
# frame=  600 fps=5.9 q=-0.0 Lsize= 1809000kB time=00:00:24.00 bitrate=617472.0kbits/s speed=0.237x
# video:1809000kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%

# %%
# !sh crop.sh UVG/HoneyBee_1920x1080_120fps_420_8bit_YUV.yuv  UVG_cropped/HoneyBee.yuv 1920 1080 1920 1072
# Out:
# frame=  600 fps=6.5 q=-0.0 Lsize= 1809000kB time=00:00:24.00 bitrate=617472.0kbits/s speed=0.26x
# video:1809000kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%

# %%
# !sh crop.sh UVG/Jockey_1920x1080_120fps_420_8bit_YUV.yuv  UVG_cropped/Jockey.yuv 1920 1080 1920 1072
# Out:
# frame=  600 fps=6.5 q=-0.0 Lsize= 1809000kB time=00:00:24.00 bitrate=617472.0kbits/s speed=0.259x
# video:1809000kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%

# %%
# !sh crop.sh UVG/ReadySteadyGo_1920x1080_120fps_420_8bit_YUV.yuv  UVG_cropped/ReadySteadyGo.yuv 1920 1080 1920 1072
# Out:
# frame=  600 fps=6.6 q=-0.0 Lsize= 1809000kB time=00:00:24.00 bitrate=617472.0kbits/s speed=0.264x
# video:1809000kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%

# %%
# !sh crop.sh UVG/ShakeNDry_1920x1080_120fps_420_8bit_YUV.yuv  UVG_cropped/ShakeNDry.yuv 1920 1080 1920 1072
# Out:
# frame=  300 fps=7.4 q=-0.0 Lsize=  904500kB time=00:00:12.00 bitrate=617472.0kbits/s speed=0.296x
# video:904500kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%

# %%
# !sh crop.sh UVG/YachtRide_1920x1080_120fps_420_8bit_YUV.yuv  UVG_cropped/YachtRide.yuv 1920 1080 1920 1072
# Out:
# frame=  600 fps=6.9 q=-0.0 Lsize= 1809000kB time=00:00:24.00 bitrate=617472.0kbits/s speed=0.276x
# video:1809000kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%

# %% [markdown]
# **H.264** <br/>
# `sh 264.sh inputfile outputfile Width Height framerate crf gop`

# %%
# !sh 264.sh UVG_cropped/Beauty.yuv UVG_mkv/Beauty_H264_15.mkv 1920 1072 120 15 12
# Out:
# H264 CRF = 15
# [libx264 @ 0x559504d99900] PSNR Mean Y:41.085 U:40.894 V:42.698 Avg:41.280 Global:41.201 kb/s:145843.39

# %%
# !sh 264.sh UVG_cropped/Beauty.yuv UVG_mkv/Beauty_H264_19.mkv 1920 1072 120 19 12
# Out:
# H264 CRF = 19
# [libx264 @ 0x5556b3391900] PSNR Mean Y:39.186 U:39.369 V:41.519 Avg:39.529 Global:39.486 kb/s:38254.25

# %%
# !sh 264.sh UVG_cropped/Beauty.yuv UVG_mkv/Beauty_H264_23.mkv 1920 1072 120 23 12
# Out:
# H264 CRF = 23
# [libx264 @ 0x55900b13f900] PSNR Mean Y:38.122 U:38.899 V:41.031 Avg:38.619 Global:38.602 kb/s:9961.50

# %%
# !sh 264.sh UVG_cropped/Beauty.yuv UVG_mkv/Beauty_H264_27.mkv 1920 1072 120 27 12
# Out:
# H264 CRF = 27
# [libx264 @ 0x55d5c0741900] PSNR Mean Y:37.091 U:38.764 V:40.736 Avg:37.782 Global:37.763 kb/s:4690.30

# %%
# !sh 264.sh UVG_cropped/Beauty.yuv UVG_mkv/Beauty_H264_31.mkv 1920 1072 120 31 12
# Out:
# H264 CRF = 31
# [libx264 @ 0x55a28034f900] PSNR Mean Y:35.658 U:38.430 V:40.179 Avg:36.547 Global:36.515 kb/s:2685.56

# %%
# !sh 264.sh UVG_cropped/Beauty.yuv UVG_mkv/Beauty_H264_35.mkv 1920 1072 120 35 12
# Out:
# H264 CRF = 35
# [libx264 @ 0x562183e81900] PSNR Mean Y:33.827 U:38.076 V:39.560 Avg:34.930 Global:34.875 kb/s:1618.09

# %%
# !sh 264.sh UVG_cropped/Beauty.yuv UVG_mkv/Beauty_H264_39.mkv 1920 1072 120 39 12
# Out:
# H264 CRF = 39
# [libx264 @ 0x55a66551d900] PSNR Mean Y:31.688 U:37.680 V:38.964 Avg:32.986 Global:32.900 kb/s:1022.79

# %%
# !sh 264.sh UVG_cropped/Bosphorus.yuv UVG_mkv/Bosphorus_H264_15.mkv 1920 1072 120 15 12
# Out:
# H264 CRF = 15
# [libx264 @ 0x5566866d1900] PSNR Mean Y:43.635 U:46.576 V:46.279 Avg:44.377 Global:44.338 kb/s:36957.91

# %%
# !sh 264.sh UVG_cropped/Bosphorus.yuv UVG_mkv/Bosphorus_H264_19.mkv 1920 1072 120 19 12
# Out:
# H264 CRF = 19
# [libx264 @ 0x55ecc16fb900] PSNR Mean Y:41.540 U:45.248 V:45.085 Avg:42.442 Global:42.408 kb/s:18006.57

# %%
# !sh 264.sh UVG_cropped/Bosphorus.yuv UVG_mkv/Bosphorus_H264_23.mkv 1920 1072 120 23 12
# Out:
# H264 CRF = 23
# [libx264 @ 0x5556ad947900] PSNR Mean Y:39.313 U:43.900 V:43.836 Avg:40.366 Global:40.330 kb/s:9620.44

# %%
# !sh 264.sh UVG_cropped/Bosphorus.yuv UVG_mkv/Bosphorus_H264_27.mkv 1920 1072 120 27 12
# Out:
# H264 CRF = 27
# [libx264 @ 0x55c9d5073900] PSNR Mean Y:37.070 U:42.685 V:42.606 Avg:38.261 Global:38.221 kb/s:5320.75

# %%
# !sh 264.sh UVG_cropped/Bosphorus.yuv UVG_mkv/Bosphorus_H264_31.mkv 1920 1072 120 31 12
# Out:
# H264 CRF = 31
# [libx264 @ 0x5651f86a9900] PSNR Mean Y:34.745 U:41.510 V:41.369 Avg:36.058 Global:36.012 kb/s:3202.64

# %%
# !sh 264.sh UVG_cropped/Bosphorus.yuv UVG_mkv/Bosphorus_H264_35.mkv 1920 1072 120 35 12
# Out:
# H264 CRF = 35
# [libx264 @ 0x558c55caf900] PSNR Mean Y:32.440 U:40.392 V:40.196 Avg:33.853 Global:33.784 kb/s:1945.41

# %%
# !sh 264.sh UVG_cropped/Bosphorus.yuv UVG_mkv/Bosphorus_H264_39.mkv 1920 1072 120 39 12
# Out:
# H264 CRF = 39
# [libx264 @ 0x55dd5555d900] PSNR Mean Y:30.415 U:39.361 V:39.172 Avg:31.897 Global:31.801 kb/s:1122.10

# %%
# !sh 264.sh UVG_cropped/HoneyBee.yuv UVG_mkv/HoneyBee_H264_15.mkv 1920 1072 120 15 12
# Out:
# H264 CRF = 15
# [libx264 @ 0x55ee7a579900] PSNR Mean Y:42.182 U:43.483 V:43.842 Avg:42.618 Global:42.586 kb/s:36893.70

# %%
# !sh 264.sh UVG_cropped/HoneyBee.yuv UVG_mkv/HoneyBee_H264_19.mkv 1920 1072 120 19 12
# Out:
# H264 CRF = 19
# [libx264 @ 0x55fac8c27900] PSNR Mean Y:41.197 U:41.997 V:42.997 Avg:41.579 Global:41.572 kb/s:12791.69

# %%
# !sh 264.sh UVG_cropped/HoneyBee.yuv UVG_mkv/HoneyBee_H264_23.mkv 1920 1072 120 23 12
# Out:
# H264 CRF = 23
# [libx264 @ 0x564bd2a27900] PSNR Mean Y:40.053 U:40.439 V:41.951 Avg:40.381 Global:40.375 kb/s:7170.75

# %%
# !sh 264.sh UVG_cropped/HoneyBee.yuv UVG_mkv/HoneyBee_H264_27.mkv 1920 1072 120 27 12
# Out:
# H264 CRF = 27
# [libx264 @ 0x55c2aa6c9900] PSNR Mean Y:38.520 U:38.938 V:40.856 Avg:38.902 Global:38.889 kb/s:4743.57

# %%
# !sh 264.sh UVG_cropped/HoneyBee.yuv UVG_mkv/HoneyBee_H264_31.mkv 1920 1072 120 31 12
# Out:
# H264 CRF = 31
# [libx264 @ 0x55b975381900] PSNR Mean Y:36.737 U:37.548 V:39.805 Avg:37.254 Global:37.230 kb/s:3327.84

# %%
# !sh 264.sh UVG_cropped/HoneyBee.yuv UVG_mkv/HoneyBee_H264_35.mkv 1920 1072 120 35 12
# Out:
# H264 CRF = 35
# [libx264 @ 0x55ee47507900] PSNR Mean Y:34.729 U:36.390 V:38.937 Avg:35.466 Global:35.435 kb/s:2431.69

# %%
# !sh 264.sh UVG_cropped/HoneyBee.yuv UVG_mkv/HoneyBee_H264_39.mkv 1920 1072 120 39 12
# Out:
# H264 CRF = 39
# [libx264 @ 0x56339c277900] PSNR Mean Y:32.561 U:35.487 V:38.168 Avg:33.542 Global:33.508 kb/s:1817.38

# %%
# !sh 264.sh UVG_cropped/Jockey.yuv UVG_mkv/Jockey_H264_15.mkv 1920 1072 120 15 12
# Out:
# H264 CRF = 15
# [libx264 @ 0x5558b183b900] PSNR Mean Y:43.179 U:44.968 V:44.552 Avg:43.640 Global:43.581 kb/s:56138.63

# %%
# !sh 264.sh UVG_cropped/Jockey.yuv UVG_mkv/Jockey_H264_19.mkv 1920 1072 120 19 12
# Out:
# H264 CRF = 19
# [libx264 @ 0x562bcf21b900] PSNR Mean Y:41.828 U:44.029 V:43.736 Avg:42.407 Global:42.349 kb/s:21660.56

# %%
# !sh 264.sh UVG_cropped/Jockey.yuv UVG_mkv/Jockey_H264_23.mkv 1920 1072 120 23 12
# Out:
# H264 CRF = 23
# [libx264 @ 0x564835589900] PSNR Mean Y:40.295 U:42.998 V:42.867 Avg:41.003 Global:40.911 kb/s:12276.25

# %%
# !sh 264.sh UVG_cropped/Jockey.yuv UVG_mkv/Jockey_H264_27.mkv 1920 1072 120 27 12
# Out:
# H264 CRF = 27
# [libx264 @ 0x55e2b361f900] PSNR Mean Y:38.262 U:41.954 V:41.951 Avg:39.170 Global:39.041 kb/s:8159.20

# %%
# !sh 264.sh UVG_cropped/Jockey.yuv UVG_mkv/Jockey_H264_31.mkv 1920 1072 120 31 12
# Out:
# H264 CRF = 31
# [libx264 @ 0x55a8c7b6d900] PSNR Mean Y:35.733 U:40.851 V:40.887 Avg:36.860 Global:36.706 kb/s:5422.98

# %%
# !sh 264.sh UVG_cropped/Jockey.yuv UVG_mkv/Jockey_H264_35.mkv 1920 1072 120 35 12
# Out:
# H264 CRF = 35
# [libx264 @ 0x555e05f97900] PSNR Mean Y:32.950 U:39.735 V:39.722 Avg:34.263 Global:34.059 kb/s:3697.36

# %%
# !sh 264.sh UVG_cropped/Jockey.yuv UVG_mkv/Jockey_H264_39.mkv 1920 1072 120 39 12
# Out:
# H264 CRF = 39
# [libx264 @ 0x562537089900] PSNR Mean Y:30.356 U:38.627 V:38.620 Avg:31.793 Global:31.519 kb/s:2799.17

# %%
# !sh 264.sh UVG_cropped/ReadySteadyGo.yuv UVG_mkv/ReadySteadyGo_H264_15.mkv 1920 1072 120 15 12
# Out:
# H264 CRF = 15
# [libx264 @ 0x557c9b75b900] PSNR Mean Y:41.227 U:43.241 V:43.236 Avg:41.797 Global:41.689 kb/s:45616.24

# %%
# !sh 264.sh UVG_cropped/ReadySteadyGo.yuv UVG_mkv/ReadySteadyGo_H264_19.mkv 1920 1072 120 19 12
# Out:
# H264 CRF = 19
# [libx264 @ 0x55a4ffc43900] PSNR Mean Y:38.859 U:41.683 V:41.842 Avg:39.625 Global:39.505 kb/s:26959.33

# %%
# !sh 264.sh UVG_cropped/ReadySteadyGo.yuv UVG_mkv/ReadySteadyGo_H264_23.mkv 1920 1072 120 23 12
# Out:
# H264 CRF = 23
# [libx264 @ 0x5633bb06d900] PSNR Mean Y:36.395 U:40.382 V:40.616 Avg:37.379 Global:37.246 kb/s:16765.65

# %%
# !sh 264.sh UVG_cropped/ReadySteadyGo.yuv UVG_mkv/ReadySteadyGo_H264_27.mkv 1920 1072 120 27 12
# Out:
# H264 CRF = 27
# [libx264 @ 0x5608976c3900] PSNR Mean Y:33.868 U:39.193 V:39.537 Avg:35.049 Global:34.904 kb/s:10608.82

# %%
# !sh 264.sh UVG_cropped/ReadySteadyGo.yuv UVG_mkv/ReadySteadyGo_H264_31.mkv 1920 1072 120 31 12
# Out:
# H264 CRF = 31
# [libx264 @ 0x563a5a0a5900] PSNR Mean Y:31.311 U:38.164 V:38.635 Avg:32.660 Global:32.503 kb/s:6882.19

# %%
# !sh 264.sh UVG_cropped/ReadySteadyGo.yuv UVG_mkv/ReadySteadyGo_H264_35.mkv 1920 1072 120 35 12
# Out:
# H264 CRF = 35
# [libx264 @ 0x55d177679900] PSNR Mean Y:28.618 U:37.188 V:37.787 Avg:30.100 Global:29.927 kb/s:4609.13

# %%
# !sh 264.sh UVG_cropped/ReadySteadyGo.yuv UVG_mkv/ReadySteadyGo_H264_39.mkv 1920 1072 120 39 12
# Out:
# H264 CRF = 39
# [libx264 @ 0x55b6ebe1f900] PSNR Mean Y:26.165 U:36.337 V:37.005 Avg:27.732 Global:27.563 kb/s:3353.94

# %%
# !sh 264.sh UVG_cropped/ShakeNDry.yuv UVG_mkv/ShakeNDry_H264_15.mkv 1920 1072 120 15 12
# Out:
# H264 CRF = 15
# [libx264 @ 0x561c9e317900] PSNR Mean Y:40.383 U:42.395 V:42.875 Avg:41.000 Global:40.902 kb/s:60033.88

# %%
# !sh 264.sh UVG_cropped/ShakeNDry.yuv UVG_mkv/ShakeNDry_H264_19.mkv 1920 1072 120 19 12
# Out:
# H264 CRF = 19
# [libx264 @ 0x55e79e025900] PSNR Mean Y:38.507 U:41.165 V:41.829 Avg:39.275 Global:39.160 kb/s:30867.47

# %%
# !sh 264.sh UVG_cropped/ShakeNDry.yuv UVG_mkv/ShakeNDry_H264_23.mkv 1920 1072 120 23 12
# Out:
# H264 CRF = 23
# [libx264 @ 0x561fcc967900] PSNR Mean Y:36.603 U:39.984 V:40.908 Avg:37.522 Global:37.383 kb/s:16429.09

# %%
# !sh 264.sh UVG_cropped/ShakeNDry.yuv UVG_mkv/ShakeNDry_H264_27.mkv 1920 1072 120 27 12
# Out:
# H264 CRF = 27
# [libx264 @ 0x55773242f900] PSNR Mean Y:34.648 U:38.812 V:40.048 Avg:35.712 Global:35.568 kb/s:8430.21

# %%
# !sh 264.sh UVG_cropped/ShakeNDry.yuv UVG_mkv/ShakeNDry_H264_31.mkv 1920 1072 120 31 12
# Out:
# H264 CRF = 31
# [libx264 @ 0x55ef00431900] PSNR Mean Y:32.732 U:37.824 V:39.349 Avg:33.940 Global:33.818 kb/s:4328.07

# %%
# !sh 264.sh UVG_cropped/ShakeNDry.yuv UVG_mkv/ShakeNDry_H264_35.mkv 1920 1072 120 35 12
# Out:
# H264 CRF = 35
# [libx264 @ 0x563412d39900] PSNR Mean Y:30.888 U:37.071 V:38.747 Avg:32.222 Global:32.139 kb/s:2459.48

# %%
# !sh 264.sh UVG_cropped/ShakeNDry.yuv UVG_mkv/ShakeNDry_H264_39.mkv 1920 1072 120 39 12
# Out:
# H264 CRF = 39
# [libx264 @ 0x561ee3feb900] PSNR Mean Y:29.010 U:36.308 V:38.095 Avg:30.443 Global:30.389 kb/s:1513.34

# %%
# !sh 264.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H264_15.mkv 1920 1072 120 15 12
# Out:
# H264 CRF = 15
# [libx264 @ 0x55c7af22f900] PSNR Mean Y:40.732 U:44.039 V:43.179 Avg:41.485 Global:41.381 kb/s:63225.03

# %%
# !sh 264.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H264_19.mkv 1920 1072 120 19 12
# Out:
# H264 CRF = 19
# [libx264 @ 0x564a50595900] PSNR Mean Y:38.235 U:42.869 V:41.944 Avg:39.223 Global:39.123 kb/s:35954.72

# %%
# !sh 264.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H264_23.mkv 1920 1072 120 23 12
# Out:
# H264 CRF = 23
# [libx264 @ 0x55b2629b5900] PSNR Mean Y:35.740 U:41.855 V:40.896 Avg:36.932 Global:36.832 kb/s:20223.96

# %%
# !sh 264.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H264_27.mkv 1920 1072 120 27 12
# Out:
# H264 CRF = 27
# [libx264 @ 0x55d07b73f900] PSNR Mean Y:33.280 U:40.925 V:39.949 Avg:34.631 Global:34.534 kb/s:11111.02

# %%
# !sh 264.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H264_31.mkv 1920 1072 120 31 12
# Out:
# H264 CRF = 31
# [libx264 @ 0x55908bd19900] PSNR Mean Y:30.861 U:40.051 V:39.021 Avg:32.328 Global:32.243 kb/s:5977.79

# %%
# !sh 264.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H264_35.mkv 1920 1072 120 35 12
# Out:
# H264 CRF = 35
# [libx264 @ 0x5599a1b35900] PSNR Mean Y:28.623 U:39.104 V:38.069 Avg:30.164 Global:30.091 kb/s:3088.70

# %%
# !sh 264.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H264_39.mkv 1920 1072 120 39 12
# Out:
# H264 CRF = 39
# [libx264 @ 0x559c01f7b900] PSNR Mean Y:26.840 U:38.237 V:37.154 Avg:28.422 Global:28.358 kb/s:1708.89

# %% [markdown]
# **H.265** <br/>
# `sh 265.sh inputfile outputfile Width Height framerate crf gop`

# %%
# !sh 265.sh UVG_cropped/Beauty.yuv UVG_mkv/Beauty_H265_15.mkv 1920 1072 120 15 12
# Out:
# H265 CRF = 15
# encoded 600 frames in 397.32s (1.51 fps), 128402.71 kb/s, Avg QP:21.56, Global PSNR: 41.338

# %%
# !sh 265.sh UVG_cropped/Beauty.yuv UVG_mkv/Beauty_H265_19.mkv 1920 1072 120 19 12
# Out:
# H265 CRF = 19
# encoded 600 frames in 210.82s (2.85 fps), 37964.09 kb/s, Avg QP:25.58, Global PSNR: 39.863

# %%
# !sh 265.sh UVG_cropped/Beauty.yuv UVG_mkv/Beauty_H265_23.mkv 1920 1072 120 23 12
# Out:
# H265 CRF = 23
# encoded 600 frames in 131.35s (4.57 fps), 9401.69 kb/s, Avg QP:29.94, Global PSNR: 39.159

# %%
# !sh 265.sh UVG_cropped/Beauty.yuv UVG_mkv/Beauty_H265_27.mkv 1920 1072 120 27 12
# Out:
# H265 CRF = 27
# encoded 600 frames in 92.79s (6.47 fps), 4320.88 kb/s, Avg QP:34.82, Global PSNR: 38.511

# %%
# !sh 265.sh UVG_cropped/Beauty.yuv UVG_mkv/Beauty_H265_31.mkv 1920 1072 120 31 12
# Out:
# H265 CRF = 31
# encoded 600 frames in 79.31s (7.57 fps), 2368.82 kb/s, Avg QP:38.99, Global PSNR: 37.654

# %%
# !sh 265.sh UVG_cropped/Beauty.yuv UVG_mkv/Beauty_H265_35.mkv 1920 1072 120 35 12
# Out:
# H265 CRF = 35
# encoded 600 frames in 69.19s (8.67 fps), 1362.79 kb/s, Avg QP:43.19, Global PSNR: 36.514

# %%
# !sh 265.sh UVG_cropped/Beauty.yuv UVG_mkv/Beauty_H265_39.mkv 1920 1072 120 39 12
# Out:
# H265 CRF = 39
# encoded 600 frames in 60.73s (9.88 fps), 778.94 kb/s, Avg QP:47.39, Global PSNR: 35.146

# %%
# !sh 265.sh UVG_cropped/Bosphorus.yuv UVG_mkv/Bosphorus_H265_15.mkv 1920 1072 120 15 12
# Out:
# H265 CRF = 15
# encoded 600 frames in 180.71s (3.32 fps), 43493.82 kb/s, Avg QP:20.00, Global PSNR: 45.396

# %%
# !sh 265.sh UVG_cropped/Bosphorus.yuv UVG_mkv/Bosphorus_H265_19.mkv 1920 1072 120 19 12
# Out:
# H265 CRF = 19
# encoded 600 frames in 136.07s (4.41 fps), 21309.36 kb/s, Avg QP:24.19, Global PSNR: 43.654

# %%
# !sh 265.sh UVG_cropped/Bosphorus.yuv UVG_mkv/Bosphorus_H265_23.mkv 1920 1072 120 23 12
# Out:
# H265 CRF = 23
# encoded 600 frames in 113.83s (5.27 fps), 11092.17 kb/s, Avg QP:28.54, Global PSNR: 41.866

# %%
# !sh 265.sh UVG_cropped/Bosphorus.yuv UVG_mkv/Bosphorus_H265_27.mkv 1920 1072 120 27 12
# Out:
# H265 CRF = 27
# encoded 600 frames in 86.51s (6.94 fps), 5891.14 kb/s, Avg QP:33.11, Global PSNR: 40.018

# %%
# !sh 265.sh UVG_cropped/Bosphorus.yuv UVG_mkv/Bosphorus_H265_31.mkv 1920 1072 120 31 12
# Out:
# H265 CRF = 31
# encoded 600 frames in 72.78s (8.24 fps), 3189.95 kb/s, Avg QP:37.49, Global PSNR: 38.162

# %%
# !sh 265.sh UVG_cropped/Bosphorus.yuv UVG_mkv/Bosphorus_H265_35.mkv 1920 1072 120 35 12
# Out:
# H265 CRF = 35
# encoded 600 frames in 63.72s (9.42 fps), 1743.56 kb/s, Avg QP:41.64, Global PSNR: 36.409

# %%
# !sh 265.sh UVG_cropped/Bosphorus.yuv UVG_mkv/Bosphorus_H265_39.mkv 1920 1072 120 39 12
# Out:
# H265 CRF = 39
# encoded 600 frames in 56.98s (10.53 fps), 958.94 kb/s, Avg QP:45.75, Global PSNR: 34.680

# %%
# !sh 265.sh UVG_cropped/HoneyBee.yuv UVG_mkv/HoneyBee_H265_15.mkv 1920 1072 120 15 12
# Out:
# H265 CRF = 15
# encoded 600 frames in 157.14s (3.82 fps), 37519.55 kb/s, Avg QP:21.61, Global PSNR: 43.312

# %%
# !sh 265.sh UVG_cropped/HoneyBee.yuv UVG_mkv/HoneyBee_H265_19.mkv 1920 1072 120 19 12
# Out:
# H265 CRF = 19
# encoded 600 frames in 97.80s (6.14 fps), 12080.05 kb/s, Avg QP:25.42, Global PSNR: 42.370

# %%
# !sh 265.sh UVG_cropped/HoneyBee.yuv UVG_mkv/HoneyBee_H265_23.mkv 1920 1072 120 23 12
# Out:
# H265 CRF = 23
# encoded 600 frames in 81.36s (7.38 fps), 6120.97 kb/s, Avg QP:29.72, Global PSNR: 41.321

# %%
# !sh 265.sh UVG_cropped/HoneyBee.yuv UVG_mkv/HoneyBee_H265_27.mkv 1920 1072 120 27 12
# Out:
# H265 CRF = 27
# encoded 600 frames in 67.67s (8.87 fps), 4004.43 kb/s, Avg QP:33.86, Global PSNR: 39.968

# %%
# !sh 265.sh UVG_cropped/HoneyBee.yuv UVG_mkv/HoneyBee_H265_31.mkv 1920 1072 120 31 12
# Out:
# H265 CRF = 31
# encoded 600 frames in 64.16s (9.35 fps), 2739.70 kb/s, Avg QP:37.88, Global PSNR: 38.317

# %%
# !sh 265.sh UVG_cropped/HoneyBee.yuv UVG_mkv/HoneyBee_H265_35.mkv 1920 1072 120 35 12
# Out:
# H265 CRF = 35
# encoded 600 frames in 60.62s (9.90 fps), 1934.69 kb/s, Avg QP:41.88, Global PSNR: 36.493

# %%
# !sh 265.sh UVG_cropped/HoneyBee.yuv UVG_mkv/HoneyBee_H265_39.mkv 1920 1072 120 39 12
# Out:
# H265 CRF = 39
# encoded 600 frames in 58.25s (10.30 fps), 1334.16 kb/s, Avg QP:45.89, Global PSNR: 34.552

# %%
# !sh 265.sh UVG_cropped/Jockey.yuv UVG_mkv/Jockey_H265_15.mkv 1920 1072 120 15 12
# Out:
# H265 CRF = 15
# encoded 600 frames in 221.40s (2.71 fps), 51080.29 kb/s, Avg QP:20.63, Global PSNR: 44.284

# %%
# !sh 265.sh UVG_cropped/Jockey.yuv UVG_mkv/Jockey_H265_19.mkv 1920 1072 120 19 12
# Out:
# H265 CRF = 19
# encoded 600 frames in 146.41s (4.10 fps), 18240.17 kb/s, Avg QP:24.64, Global PSNR: 43.258

# %%
# !sh 265.sh UVG_cropped/Jockey.yuv UVG_mkv/Jockey_H265_23.mkv 1920 1072 120 23 12
# Out:
# H265 CRF = 23
# encoded 600 frames in 126.52s (4.74 fps), 9230.02 kb/s, Avg QP:28.71, Global PSNR: 42.220

# %%
# !sh 265.sh UVG_cropped/Jockey.yuv UVG_mkv/Jockey_H265_27.mkv 1920 1072 120 27 12
# Out:
# H265 CRF = 27
# encoded 600 frames in 100.88s (5.95 fps), 5592.32 kb/s, Avg QP:32.79, Global PSNR: 40.930

# %%
# !sh 265.sh UVG_cropped/Jockey.yuv UVG_mkv/Jockey_H265_31.mkv 1920 1072 120 31 12
# Out:
# H265 CRF = 31
# encoded 600 frames in 89.07s (6.74 fps), 3582.09 kb/s, Avg QP:36.92, Global PSNR: 39.350

# %%
# !sh 265.sh UVG_cropped/Jockey.yuv UVG_mkv/Jockey_H265_35.mkv 1920 1072 120 35 12
# Out:
# H265 CRF = 35
# encoded 600 frames in 79.29s (7.57 fps), 2297.70 kb/s, Avg QP:41.17, Global PSNR: 37.536

# %%
# !sh 265.sh UVG_cropped/Jockey.yuv UVG_mkv/Jockey_H265_39.mkv 1920 1072 120 39 12
# Out:
# H265 CRF = 39
# encoded 600 frames in 70.00s (8.57 fps), 1434.92 kb/s, Avg QP:45.55, Global PSNR: 35.526

# %%
# !sh 265.sh UVG_cropped/ReadySteadyGo.yuv UVG_mkv/ReadySteadyGo_H265_15.mkv 1920 1072 120 15 12
# Out:
# H265 CRF = 15
# encoded 600 frames in 166.73s (3.60 fps), 46943.92 kb/s, Avg QP:22.49, Global PSNR: 43.239

# %%
# !sh 265.sh UVG_cropped/ReadySteadyGo.yuv UVG_mkv/ReadySteadyGo_H265_19.mkv 1920 1072 120 19 12
# Out:
# H265 CRF = 19
# encoded 600 frames in 128.84s (4.66 fps), 27385.62 kb/s, Avg QP:26.72, Global PSNR: 41.236

# %%
# !sh 265.sh UVG_cropped/ReadySteadyGo.yuv UVG_mkv/ReadySteadyGo_H265_23.mkv 1920 1072 120 23 12
# Out:
# H265 CRF = 23
# encoded 600 frames in 119.83s (5.01 fps), 16879.83 kb/s, Avg QP:30.96, Global PSNR: 39.140

# %%
# !sh 265.sh UVG_cropped/ReadySteadyGo.yuv UVG_mkv/ReadySteadyGo_H265_27.mkv 1920 1072 120 27 12
# Out:
# H265 CRF = 27
# encoded 600 frames in 98.60s (6.08 fps), 10584.41 kb/s, Avg QP:35.25, Global PSNR: 36.978

# %%
# !sh 265.sh UVG_cropped/ReadySteadyGo.yuv UVG_mkv/ReadySteadyGo_H265_31.mkv 1920 1072 120 31 12
# Out:
# H265 CRF = 31
# encoded 600 frames in 88.16s (6.81 fps), 6613.67 kb/s, Avg QP:39.34, Global PSNR: 34.833

# %%
# !sh 265.sh UVG_cropped/ReadySteadyGo.yuv UVG_mkv/ReadySteadyGo_H265_35.mkv 1920 1072 120 35 12
# Out:
# H265 CRF = 35
# encoded 600 frames in 78.78s (7.62 fps), 4030.97 kb/s, Avg QP:43.42, Global PSNR: 32.653

# %%
# !sh 265.sh UVG_cropped/ReadySteadyGo.yuv UVG_mkv/ReadySteadyGo_H265_39.mkv 1920 1072 120 39 12
# Out:
# H265 CRF = 39
# encoded 600 frames in 70.35s (8.53 fps), 2347.51 kb/s, Avg QP:47.46, Global PSNR: 30.449

# %%
# !sh 265.sh UVG_cropped/ShakeNDry.yuv UVG_mkv/ShakeNDry_H265_15.mkv 1920 1072 120 15 12
# Out:
# H265 CRF = 15
# encoded 300 frames in 98.61s (3.04 fps), 56400.08 kb/s, Avg QP:23.70, Global PSNR: 42.009

# %%
# !sh 265.sh UVG_cropped/ShakeNDry.yuv UVG_mkv/ShakeNDry_H265_19.mkv 1920 1072 120 19 12
# Out:
# H265 CRF = 19
# encoded 300 frames in 73.50s (4.08 fps), 29474.19 kb/s, Avg QP:27.65, Global PSNR: 40.424

# %%
# !sh 265.sh UVG_cropped/ShakeNDry.yuv UVG_mkv/ShakeNDry_H265_23.mkv 1920 1072 120 23 12
# Out:
# H265 CRF = 23
# encoded 300 frames in 62.15s (4.83 fps), 16134.70 kb/s, Avg QP:31.71, Global PSNR: 38.757

# %%
# !sh 265.sh UVG_cropped/ShakeNDry.yuv UVG_mkv/ShakeNDry_H265_27.mkv 1920 1072 120 27 12
# Out:
# H265 CRF = 27
# encoded 300 frames in 47.51s (6.31 fps), 8648.26 kb/s, Avg QP:35.83, Global PSNR: 36.984

# %%
# !sh 265.sh UVG_cropped/ShakeNDry.yuv UVG_mkv/ShakeNDry_H265_31.mkv 1920 1072 120 31 12
# Out:
# H265 CRF = 31
# encoded 300 frames in 39.65s (7.57 fps), 4462.27 kb/s, Avg QP:39.89, Global PSNR: 35.205

# %%
# !sh 265.sh UVG_cropped/ShakeNDry.yuv UVG_mkv/ShakeNDry_H265_35.mkv 1920 1072 120 35 12
# Out:
# H265 CRF = 35
# encoded 300 frames in 33.04s (9.08 fps), 2267.97 kb/s, Avg QP:43.93, Global PSNR: 33.449

# %%
# !sh 265.sh UVG_cropped/ShakeNDry.yuv UVG_mkv/ShakeNDry_H265_39.mkv 1920 1072 120 39 12
# Out:
# H265 CRF = 39
# encoded 300 frames in 29.69s (10.10 fps), 1218.04 kb/s, Avg QP:47.89, Global PSNR: 31.741

# %%
# !sh 265.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H265_15.mkv 1920 1072 120 15 12
# Out:
# H265 CRF = 15
# encoded 600 frames in 204.09s (2.94 fps), 69767.23 kb/s, Avg QP:22.46, Global PSNR: 42.860

# %%
# !sh 265.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H265_15.mkv 1920 1072 120 15 12
# Out:
# H265 CRF = 15
# encoded 600 frames in 190.71s (3.15 fps), 69767.23 kb/s, Avg QP:22.46, Global PSNR: 42.860

# %%
# !sh 265.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H265_19.mkv 1920 1072 120 19 12
# Out:
# H265 CRF = 19
# encoded 600 frames in 221.46s (2.71 fps), 40609.48 kb/s, Avg QP:26.59, Global PSNR: 40.703

# %%
# !sh 265.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H265_23.mkv 1920 1072 120 23 12
# Out:
# H265 CRF = 23
# encoded 600 frames in 143.70s (4.18 fps), 23204.10 kb/s, Avg QP:30.75, Global PSNR: 38.556

# %%
# !sh 265.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H265_27.mkv 1920 1072 120 27 12
# Out:
# H265 CRF = 27
# encoded 600 frames in 111.95s (5.36 fps), 12759.86 kb/s, Avg QP:35.00, Global PSNR: 36.466

# %%
# !sh 265.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H265_31.mkv 1920 1072 120 31 12
# Out:
# H265 CRF = 31
# encoded 600 frames in 91.23s (6.58 fps), 6591.94 kb/s, Avg QP:39.29, Global PSNR: 34.501

# %%
# !sh 265.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H265_35.mkv 1920 1072 120 35 12
# Out:
# H265 CRF = 35
# encoded 600 frames in 74.07s (8.10 fps), 3161.45 kb/s, Avg QP:43.64, Global PSNR: 32.628

# %%
# !sh 265.sh UVG_cropped/YachtRide.yuv UVG_mkv/YachtRide_H265_39.mkv 1920 1072 120 39 12
# Out:
# H265 CRF = 39
# encoded 600 frames in 61.11s (9.82 fps), 1412.19 kb/s, Avg QP:47.84, Global PSNR: 30.842

# %% [markdown]
# **Extract pngs** <br/>
#  sh extract_png.sh inputfile outputfile Width Height framerate

# %%
# !sh extract_png.sh UVG_cropped/Beauty.yuv  UVG_frames/Beauty/im%d.png 1920 1072 120
# Out:
# frame=  600 fps=1.0 q=-0.0 Lsize=N/A time=00:00:24.00 bitrate=N/A speed=0.0406x
# video:2871195kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_png.sh UVG_cropped/Bosphorus.yuv  UVG_frames/Bosphorus/im%d.png 1920 1072 120
# Out:
# frame=  600 fps=2.6 q=-0.0 Lsize=N/A time=00:00:24.00 bitrate=N/A speed=0.104x
# video:1691112kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_png.sh UVG_cropped/HoneyBee.yuv  UVG_frames/Honeybee/im%d.png 1920 1072 120
# Out:
# frame=  600 fps=2.5 q=-0.0 Lsize=N/A time=00:00:24.00 bitrate=N/A speed=0.098x
# video:2991361kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_png.sh UVG_cropped/Jockey.yuv  UVG_frames/Jockey/im%d.png 1920 1072 120
# Out:
# frame=  600 fps=2.7 q=-0.0 Lsize=N/A time=00:00:24.00 bitrate=N/A speed=0.107x
# video:2237847kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_png.sh UVG_cropped/ReadySteadyGo.yuv  UVG_frames/ReadySetGo/im%d.png 1920 1072 120
# Out:
# frame=  600 fps=2.6 q=-0.0 Lsize=N/A time=00:00:24.00 bitrate=N/A speed=0.102x
# video:2358952kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_png.sh UVG_cropped/ShakeNDry.yuv  UVG_frames/ShakeNDry/im%d.png 1920 1072 120
# Out:
# frame=  300 fps=1.8 q=-0.0 Lsize=N/A time=00:00:12.00 bitrate=N/A speed=0.0703x
# video:1429331kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_png.sh UVG_cropped/YachtRide.yuv  UVG_frames/YachtRide/im%d.png 1920 1072 120
# Out:
# frame=  600 fps=2.7 q=-0.0 Lsize=N/A time=00:00:24.00 bitrate=N/A speed=0.107x
# video:1817509kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %% [markdown]
# ## Extract compressed pngs

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Beauty_H264_15.mkv UVG_compressed_PNGS/Beauty/H264_15/im%d.png
# Out:
# frame=  600 fps=3.8 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0317x
# video:2203758kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Beauty_H264_19.mkv UVG_compressed_PNGS/Beauty/H264_19/im%d.png
# Out:
# frame=  600 fps=4.7 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0388x
# video:1545642kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Beauty_H264_23.mkv UVG_compressed_PNGS/Beauty/H264_23/im%d.png
# Out:
# frame=  600 fps=1.3 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0108x
# video:1069455kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Beauty_H264_27.mkv UVG_compressed_PNGS/Beauty/H264_27/im%d.png
# Out:
# frame=  600 fps=4.8 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0397x
# video:776138kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Beauty_H264_31.mkv UVG_compressed_PNGS/Beauty/H264_31/im%d.png
# Out:
# frame=  600 fps=4.9 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0409x
# video:688908kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Beauty_H264_35.mkv UVG_compressed_PNGS/Beauty/H264_35/im%d.png
# Out:
# frame=  600 fps=5.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0421x
# video:608118kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Beauty_H264_39.mkv UVG_compressed_PNGS/Beauty/H264_39/im%d.png
# Out:
# frame=  600 fps=5.6 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0468x
# video:528365kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Beauty_H265_15.mkv UVG_compressed_PNGS/Beauty/H265_15/im%d.png
# Out:
# frame=  600 fps=3.6 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0301x
# video:2225065kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Beauty_H265_19.mkv UVG_compressed_PNGS/Beauty/H265_19/im%d.png
# Out:
# frame=  600 fps=4.7 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0392x
# video:1545642kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Beauty_H265_23.mkv UVG_compressed_PNGS/Beauty/H265_23/im%d.png
# Out:
# frame=  600 fps=1.2 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0103x
# video:1414128kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Beauty_H265_27.mkv UVG_compressed_PNGS/Beauty/H265_27/im%d.png
# Out:
# frame=  600 fps=4.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0333x
# video:1138846kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Beauty_H265_31.mkv UVG_compressed_PNGS/Beauty/H265_31/im%d.png
# Out:
# frame=  600 fps=4.4 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0366x
# video:984967kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Beauty_H265_35.mkv UVG_compressed_PNGS/Beauty/H265_35/im%d.png
# Out:
# frame=  600 fps=4.6 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0387x
# video:878071kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Beauty_H265_39.mkv UVG_compressed_PNGS/Beauty/H265_39/im%d.png
# Out:
# frame=  600 fps=5.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0417x
# video:740251kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Bosphorus_H264_15.mkv UVG_compressed_PNGS/Bosphorus/H264_15/im%d.png
# Out:
# frame=  600 fps=5.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0415x
# video:1254310kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Bosphorus_H264_19.mkv UVG_compressed_PNGS/Bosphorus/H264_19/im%d.png
# Out:
# frame=  600 fps=5.6 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0463x
# video:1114433kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Bosphorus_H264_23.mkv UVG_compressed_PNGS/Bosphorus/H264_23/im%d.png
# Out:
# frame=  600 fps=4.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0336x
# video:1012209kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Bosphorus_H264_27.mkv UVG_compressed_PNGS/Bosphorus/H264_27/im%d.png
# Out:
# frame=  600 fps=4.3 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0361x
# video:906557kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Bosphorus_H264_31.mkv UVG_compressed_PNGS/Bosphorus/H264_31/im%d.png
# Out:
# frame=  600 fps=4.5 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0377x
# video:800753kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Bosphorus_H264_35.mkv UVG_compressed_PNGS/Bosphorus/H264_35/im%d.png
# Out:
# frame=  600 fps=5.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0418x
# video:678871kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Bosphorus_H264_39.mkv UVG_compressed_PNGS/Bosphorus/H264_39/im%d.png
# Out:
# frame=  600 fps=5.4 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0447x
# video:547795kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Bosphorus_H265_15.mkv UVG_compressed_PNGS/Bosphorus/H265_15/im%d.png
# Out:
# frame=  600 fps=4.8 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0397x
# video:1314621kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Bosphorus_H265_19.mkv UVG_compressed_PNGS/Bosphorus/H265_19/im%d.png
# Out:
# frame=  600 fps=5.2 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0437x
# video:1270568kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Bosphorus_H265_23.mkv UVG_compressed_PNGS/Bosphorus/H265_23/im%d.png
# Out:
# frame=  600 fps=3.7 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0305x
# video:1215549kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Bosphorus_H265_27.mkv UVG_compressed_PNGS/Bosphorus/H265_27/im%d.png
# Out:
# frame=  600 fps=3.7 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0312x
# video:1166138kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Bosphorus_H265_31.mkv UVG_compressed_PNGS/Bosphorus/H265_31/im%d.png
# Out:
# frame=  600 fps=3.8 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0319x
# video:1128095kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Bosphorus_H265_35.mkv UVG_compressed_PNGS/Bosphorus/H265_35/im%d.png
# Out:
# frame=  600 fps=4.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0337x
# video:1035573kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Bosphorus_H265_39.mkv UVG_compressed_PNGS/Bosphorus/H265_39/im%d.png
# Out:
# frame=  600 fps=4.4 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.037x
# video:865511kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/HoneyBee_H264_15.mkv UVG_compressed_PNGS/HoneyBee/H264_15/im%d.png
# Out:
# frame=  600 fps=4.2 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0348x
# video:2480773kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/HoneyBee_H264_19.mkv UVG_compressed_PNGS/HoneyBee/H264_19/im%d.png
# Out:
# frame=  600 fps=4.6 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0382x
# video:2165192kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/HoneyBee_H264_23.mkv UVG_compressed_PNGS/HoneyBee/H264_23/im%d.png
# Out:
# frame=  600 fps=3.5 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0288x
# video:2004184kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/HoneyBee_H264_27.mkv UVG_compressed_PNGS/HoneyBee/H264_27/im%d.png
# Out:
# frame=  600 fps=3.5 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0295x
# video:1884313kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/HoneyBee_H264_31.mkv UVG_compressed_PNGS/HoneyBee/H264_31/im%d.png
# Out:
# frame=  600 fps=3.7 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0309x
# video:1740993kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/HoneyBee_H264_35.mkv UVG_compressed_PNGS/HoneyBee/H264_35/im%d.png
# Out:
# frame=  600 fps=3.9 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0322x
# video:1560667kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/HoneyBee_H264_39.mkv UVG_compressed_PNGS/HoneyBee/H264_39/im%d.png
# Out:
# frame=  600 fps=4.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0331x
# video:1368449kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/HoneyBee_H265_15.mkv UVG_compressed_PNGS/HoneyBee/H265_15/im%d.png
# Out:
# frame=  600 fps=4.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.033x
# video:2471421kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/HoneyBee_H265_19.mkv UVG_compressed_PNGS/HoneyBee/H265_19/im%d.png
# Out:
# frame=  600 fps=4.2 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0349x
# video:2341421kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/HoneyBee_H265_23.mkv UVG_compressed_PNGS/HoneyBee/H265_23/im%d.png
# Out:
# frame=  600 fps=3.2 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0267x
# video:2332681kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/HoneyBee_H265_27.mkv UVG_compressed_PNGS/HoneyBee/H265_27/im%d.png
# Out:
# frame=  600 fps=3.1 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0261x
# video:2383625kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/HoneyBee_H265_31.mkv UVG_compressed_PNGS/HoneyBee/H265_31/im%d.png
# Out:
# frame=  600 fps=3.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0254x
# video:2399203kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/HoneyBee_H265_35.mkv UVG_compressed_PNGS/HoneyBee/H265_35/im%d.png
# Out:
# frame=  600 fps=3.1 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0258x
# video:2355079kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/HoneyBee_H265_39.mkv UVG_compressed_PNGS/HoneyBee/H265_39/im%d.png
# Out:
# frame=  600 fps=3.2 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0267x
# video:2265396kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Jockey_H264_15.mkv UVG_compressed_PNGS/Jockey/H264_15/im%d.png
# Out:
# frame=  600 fps=4.7 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0394x
# video:1434137kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Jockey_H264_19.mkv UVG_compressed_PNGS/Jockey/H264_19/im%d.png
# Out:
# frame=  600 fps=5.9 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0493x
# video:1109162kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Jockey_H264_23.mkv UVG_compressed_PNGS/Jockey/H264_23/im%d.png
# Out:
# frame=  600 fps=1.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.00848x
# video:969194kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Jockey_H264_27.mkv UVG_compressed_PNGS/Jockey/H264_27/im%d.png
# Out:
# frame=  600 fps=0.9 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.00755x
# video:879220kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Jockey_H264_31.mkv UVG_compressed_PNGS/Jockey/H264_31/im%d.png
# Out:
# frame=  600 fps=4.3 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0356x
# video:817313kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Jockey_H264_35.mkv UVG_compressed_PNGS/Jockey/H264_35/im%d.png
# Out:
# frame=  600 fps=4.4 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0365x
# video:753735kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Jockey_H264_39.mkv UVG_compressed_PNGS/Jockey/H264_39/im%d.png
# Out:
# frame=  600 fps=4.6 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0386x
# video:690251kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Jockey_H265_15.mkv UVG_compressed_PNGS/Jockey/H265_15/im%d.png
# Out:
# frame=  600 fps=4.4 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0365x
# video:1515862kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Jockey_H265_19.mkv UVG_compressed_PNGS/Jockey/H265_19/im%d.png
# Out:
# frame=  600 fps=5.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0414x
# video:1337079kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Jockey_H265_23.mkv UVG_compressed_PNGS/Jockey/H265_23/im%d.png
# Out:
# frame=  600 fps=3.7 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0307x
# video:1240879kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Jockey_H265_27.mkv UVG_compressed_PNGS/Jockey/H265_27/im%d.png
# Out:
# frame=  600 fps=3.7 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0311x
# video:1189586kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Jockey_H265_31.mkv UVG_compressed_PNGS/Jockey/H265_31/im%d.png
# Out:
# frame=  600 fps=3.8 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.032x
# video:1164178kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Jockey_H265_35.mkv UVG_compressed_PNGS/Jockey/H265_35/im%d.png
# Out:
# frame=  600 fps=4.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.033x
# video:1083924kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/Jockey_H265_39.mkv UVG_compressed_PNGS/Jockey/H265_39/im%d.png
# Out:
# frame=  600 fps=4.4 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0363x
# video:950048kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ReadySteadyGo_H264_15.mkv UVG_compressed_PNGS/ReadySetGo/H264_15/im%d.png
# Out:
# frame=  600 fps=1.1 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.00879x
# video:1822988kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ReadySteadyGo_H264_19.mkv UVG_compressed_PNGS/ReadySetGo/H264_19/im%d.png
# Out:
# frame=  600 fps=1.1 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.00956x
# video:1728616kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ReadySteadyGo_H264_23.mkv UVG_compressed_PNGS/ReadySetGo/H264_23/im%d.png
# Out:
# frame=  600 fps=1.3 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0107x
# video:1657244kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ReadySteadyGo_H264_27.mkv UVG_compressed_PNGS/ReadySetGo/H264_27/im%d.png
# Out:
# frame=  600 fps=1.3 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.011x
# video:1583989kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ReadySteadyGo_H264_31.mkv UVG_compressed_PNGS/ReadySetGo/H264_31/im%d.png
# Out:
# frame=  600 fps=1.3 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0112x
# video:1498735kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ReadySteadyGo_H264_35.mkv UVG_compressed_PNGS/ReadySetGo/H264_35/im%d.png
# Out:
# frame=  600 fps=1.4 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0114x
# video:1396441kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ReadySteadyGo_H264_39.mkv UVG_compressed_PNGS/ReadySetGo/H264_39/im%d.png
# Out:
# frame=  600 fps=1.4 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0114x
# video:1264894kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ReadySteadyGo_H265_15.mkv UVG_compressed_PNGS/ReadySetGo/H265_15/im%d.png
# Out:
# frame=  600 fps=4.4 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0367x
# video:1951882kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ReadySteadyGo_H265_19.mkv UVG_compressed_PNGS/ReadySetGo/H265_19/im%d.png
# Out:
# frame=  600 fps=4.6 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0381x
# video:1917290kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ReadySteadyGo_H265_23.mkv UVG_compressed_PNGS/ReadySetGo/H265_23/im%d.png
# Out:
# frame=  600 fps=3.4 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0286x
# video:1896010kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ReadySteadyGo_H265_27.mkv UVG_compressed_PNGS/ReadySetGo/H265_27/im%d.png
# Out:
# frame=  600 fps=3.5 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0294x
# video:1890728kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ReadySteadyGo_H265_31.mkv UVG_compressed_PNGS/ReadySetGo/H265_31/im%d.png
# Out:
# frame=  600 fps=3.5 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.029x
# video:1878291kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ReadySteadyGo_H265_35.mkv UVG_compressed_PNGS/ReadySetGo/H265_35/im%d.png
# Out:
# frame=  600 fps=3.6 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0299x
# video:1826210kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ReadySteadyGo_H265_39.mkv UVG_compressed_PNGS/ReadySetGo/H265_39/im%d.png
# Out:
# frame=  600 fps=3.7 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0305x
# video:1672712kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ShakeNDry_H264_15.mkv UVG_compressed_PNGS/ShakeNDry/H264_15/im%d.png
# Out:
# frame=  300 fps=4.0 q=-0.0 Lsize=N/A time=00:00:02.50 bitrate=N/A speed=0.0333x
# video:1215415kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ShakeNDry_H264_19.mkv UVG_compressed_PNGS/ShakeNDry/H264_19/im%d.png
# Out:
# frame=  300 fps=4.2 q=-0.0 Lsize=N/A time=00:00:02.50 bitrate=N/A speed=0.0351x
# video:1120552kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ShakeNDry_H264_23.mkv UVG_compressed_PNGS/ShakeNDry/H264_23/im%d.png
# Out:
# frame=  300 fps=2.3 q=-0.0 Lsize=N/A time=00:00:02.50 bitrate=N/A speed=0.0191x
# video:1050056kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ShakeNDry_H264_27.mkv UVG_compressed_PNGS/ShakeNDry/H264_27/im%d.png
# Out:
# frame=  300 fps=2.4 q=-0.0 Lsize=N/A time=00:00:02.50 bitrate=N/A speed=0.02x
# video:967967kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ShakeNDry_H264_31.mkv UVG_compressed_PNGS/ShakeNDry/H264_31/im%d.png
# Out:
# frame=  300 fps=2.6 q=-0.0 Lsize=N/A time=00:00:02.50 bitrate=N/A speed=0.0213x
# video:861057kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ShakeNDry_H264_35.mkv UVG_compressed_PNGS/ShakeNDry/H264_35/im%d.png
# Out:
# frame=  300 fps=2.7 q=-0.0 Lsize=N/A time=00:00:02.50 bitrate=N/A speed=0.0227x
# video:731822kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ShakeNDry_H264_39.mkv UVG_compressed_PNGS/ShakeNDry/H264_39/im%d.png
# Out:
# frame=  300 fps=3.0 q=-0.0 Lsize=N/A time=00:00:02.50 bitrate=N/A speed=0.0247x
# video:587952kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ShakeNDry_H265_15.mkv UVG_compressed_PNGS/ShakeNDry/H265_15/im%d.png
# Out:
# frame=  300 fps=3.8 q=-0.0 Lsize=N/A time=00:00:02.50 bitrate=N/A speed=0.0315x
# video:1245717kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ShakeNDry_H265_19.mkv UVG_compressed_PNGS/ShakeNDry/H265_19/im%d.png
# Out:
# frame=  300 fps=3.9 q=-0.0 Lsize=N/A time=00:00:02.50 bitrate=N/A speed=0.0329x
# video:1226911kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ShakeNDry_H265_23.mkv UVG_compressed_PNGS/ShakeNDry/H265_23/im%d.png
# Out:
# frame=  300 fps=2.2 q=-0.0 Lsize=N/A time=00:00:02.50 bitrate=N/A speed=0.0187x
# video:1214178kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ShakeNDry_H265_27.mkv UVG_compressed_PNGS/ShakeNDry/H265_27/im%d.png
# Out:
# frame=  300 fps=2.2 q=-0.0 Lsize=N/A time=00:00:02.50 bitrate=N/A speed=0.0186x
# video:1188339kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ShakeNDry_H265_31.mkv UVG_compressed_PNGS/ShakeNDry/H265_31/im%d.png
# Out:
# frame=  300 fps=2.3 q=-0.0 Lsize=N/A time=00:00:02.50 bitrate=N/A speed=0.019x
# video:1147786kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ShakeNDry_H265_35.mkv UVG_compressed_PNGS/ShakeNDry/H265_35/im%d.png
# Out:
# frame=  300 fps=2.2 q=-0.0 Lsize=N/A time=00:00:02.50 bitrate=N/A speed=0.0187x
# video:1072219kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/ShakeNDry_H265_39.mkv UVG_compressed_PNGS/ShakeNDry/H265_39/im%d.png
# Out:
# frame=  300 fps=2.5 q=-0.0 Lsize=N/A time=00:00:02.50 bitrate=N/A speed=0.0209x
# video:910176kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/YachtRide_H264_15.mkv UVG_compressed_PNGS/YachtRide/H264_15/im%d.png
# Out:
# frame=  600 fps=4.6 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0384x
# video:1428611kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/YachtRide_H264_19.mkv UVG_compressed_PNGS/YachtRide/H264_19/im%d.png
# Out:
# frame=  600 fps=5.1 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0428x
# video:1315922kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/YachtRide_H264_23.mkv UVG_compressed_PNGS/YachtRide/H264_23/im%d.png
# Out:
# frame=  600 fps=3.8 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.032x
# video:1223645kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/YachtRide_H264_27.mkv UVG_compressed_PNGS/YachtRide/H264_27/im%d.png
# Out:
# frame=  600 fps=3.9 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0328x
# video:1128370kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/YachtRide_H264_31.mkv UVG_compressed_PNGS/YachtRide/H264_31/im%d.png
# Out:
# frame=  600 fps=4.3 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0356x
# video:1029083kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/YachtRide_H264_35.mkv UVG_compressed_PNGS/YachtRide/H264_35/im%d.png
# Out:
# frame=  600 fps=4.6 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0383x
# video:898728kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/YachtRide_H264_39.mkv UVG_compressed_PNGS/YachtRide/H264_39/im%d.png
# Out:
# frame=  600 fps=5.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0417x
# video:735450kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/YachtRide_H265_15.mkv UVG_compressed_PNGS/YachtRide/H265_15/im%d.png
# Out:
# frame=  600 fps=4.0 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0335x
# video:1547109kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/YachtRide_H265_19.mkv UVG_compressed_PNGS/YachtRide/H265_19/im%d.png
# Out:
# frame=  600 fps=4.2 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0351x
# video:1521565kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/YachtRide_H265_23.mkv UVG_compressed_PNGS/YachtRide/H265_23/im%d.png
# Out:
# frame=  600 fps=3.4 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0284x
# video:1470166kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/YachtRide_H265_27.mkv UVG_compressed_PNGS/YachtRide/H265_27/im%d.png
# Out:
# frame=  600 fps=3.5 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0293x
# video:1406744kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/YachtRide_H265_31.mkv UVG_compressed_PNGS/YachtRide/H265_31/im%d.png
# Out:
# frame=  600 fps=3.6 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0301x
# video:1350152kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/YachtRide_H265_35.mkv UVG_compressed_PNGS/YachtRide/H265_35/im%d.png
# Out:
# frame=  600 fps=3.9 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0323x
# video:1246988kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !sh extract_compressed_pngs.sh UVG_mkv/YachtRide_H265_39.mkv UVG_compressed_PNGS/YachtRide/H265_39/im%d.png
# Out:
# frame=  600 fps=4.3 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=0.0358x
# video:1033887kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %% [markdown]
# **Ours** <br/>
# python experiment.py -i inputDir -m model -g GOP

# %%
# !python experiment.py -i UVG_frames/Beauty/ -m checkpoints/videocompressor8192.pkl -g 12
# Out:
# Average
# psnr = 35.02860298,  bpp = 0.82923096, ms-ssim =0.93255254

# %%
# !python experiment.py -i UVG_frames/Beauty/ -m checkpoints/videocompressor4096.pkl -g 12
# Out:
# Average
# psnr = 33.88571968,  bpp = 0.36996886, ms-ssim =0.90743338

# %%
# !python experiment.py -i UVG_frames/Beauty/ -m checkpoints/videocompressor2048.pkl -g 12
# Out:
# Average
# psnr = 33.06644630,  bpp = 0.16861471, ms-ssim =0.88501286

# %%
# !python experiment.py -i UVG_frames/Beauty/ -m checkpoints/videocompressor1024.pkl -g 12
# Out:
# Average
# psnr = 32.63400917,  bpp = 0.08939403, ms-ssim =0.87202216

# %%
# !python experiment.py -i UVG_frames/Beauty/ -m checkpoints/videocompressor512.pkl -g 12
# Out:
# Average
# psnr = 32.35089874,  bpp = 0.04813554, ms-ssim =0.86460425

# %%
# !python experiment.py -i UVG_frames/Beauty/ -m checkpoints/videocompressor256.pkl -g 12
# Out:
# Average
# psnr = 31.88634682,  bpp = 0.03129114, ms-ssim =0.85341030

# %%
# !python experiment.py -i UVG_frames/Beauty/ -m checkpoints/videocompressor128.pkl -g 12
# Out:
# Average
# psnr = 31.17720680,  bpp = 0.02132161, ms-ssim =0.83625057

# %%
# !python experiment.py -i UVG_frames/Beauty/ -m checkpoints/videocompressor256-msssim.pkl -g 12
# Out:
# Average
# psnr = 33.96925774,  bpp = 0.56242667, ms-ssim =0.92945051

# %%
# !python experiment.py -i UVG_frames/Beauty/ -m checkpoints/videocompressor128-msssim.pkl -g 12
# Out:
# Average
# psnr = 33.23322792,  bpp = 0.27332722, ms-ssim =0.90841048

# %%
# !python experiment.py -i UVG_frames/Beauty/ -m checkpoints/videocompressor64-msssim.pkl -g 12
# Out:
# Average
# psnr = 33.09295197,  bpp = 0.18600742, ms-ssim =0.90114907

# %%
# !python experiment.py -i UVG_frames/Beauty/ -m checkpoints/videocompressor32-msssim.pkl -g 12
# Out:
# Average
# psnr = 33.03334579,  bpp = 0.14577297, ms-ssim =0.89463236

# %%
# !python experiment.py -i UVG_frames/Beauty/ -m checkpoints/videocompressor16-msssim.pkl -g 12
# Out:
# Average
# psnr = 32.85889244,  bpp = 0.09799155, ms-ssim =0.88803806

# %%
# !python experiment.py -i UVG_frames/Beauty/ -m checkpoints/videocompressor8-msssim.pkl -g 12
# Out:
# Average
# psnr = 32.51328411,  bpp = 0.05253912, ms-ssim =0.87930411

# %%
# !python experiment.py -i UVG_frames/Bosphorus/ -m checkpoints/videocompressor8192.pkl -g 12
# Out:
# Average
# psnr = 41.47864075,  bpp = 0.34388718, ms-ssim =0.99050549

# %%
# !python experiment.py -i UVG_frames/Bosphorus/ -m checkpoints/videocompressor4096.pkl -g 12
# Out:
# Average
# psnr = 39.80131264,  bpp = 0.17531427, ms-ssim =0.98664829

# %%
# !python experiment.py -i UVG_frames/Bosphorus/ -m checkpoints/videocompressor2048.pkl -g 12
# Out:
# Average
# psnr = 38.62977333,  bpp = 0.11309731, ms-ssim =0.98286215

# %%
# !python experiment.py -i UVG_frames/Bosphorus/ -m checkpoints/videocompressor1024.pkl -g 12
# Out:
# Average
# psnr = 37.72649460,  bpp = 0.07188014, ms-ssim =0.97928841

# %%
# !python experiment.py -i UVG_frames/Bosphorus/ -m checkpoints/videocompressor512.pkl -g 12
# Out:
# Average
# psnr = 36.94909706,  bpp = 0.04342424, ms-ssim =0.97564101

# %%
# !python experiment.py -i UVG_frames/Bosphorus/ -m checkpoints/videocompressor256.pkl -g 12
# Out:
# Average
# psnr = 36.27579041,  bpp = 0.02946460, ms-ssim =0.97131062

# %%
# !python experiment.py -i UVG_frames/Bosphorus/ -m checkpoints/videocompressor128.pkl -g 12
# Out:
# Average
# psnr = 35.33340263,  bpp = 0.02030094, ms-ssim =0.96195750

# %%
# !python experiment.py -i UVG_frames/Bosphorus/ -m checkpoints/videocompressor256-msssim.pkl -g 12
# Out:
# Average
# psnr = 40.63815498,  bpp = 0.37191198, ms-ssim =0.99196186

# %%
# !python experiment.py -i UVG_frames/Bosphorus/ -m checkpoints/videocompressor128-msssim.pkl -g 12
# Out:
# Average
# psnr = 38.50313797,  bpp = 0.17431459, ms-ssim =0.98688223

# %%
# !python experiment.py -i UVG_frames/Bosphorus/ -m checkpoints/videocompressor64-msssim.pkl -g 12
# Out:
# Average
# psnr = 38.17530212,  bpp = 0.12108872, ms-ssim =0.98547190

# %%
# !python experiment.py -i UVG_frames/Bosphorus/ -m checkpoints/videocompressor32-msssim.pkl -g 12
# Out:
# Average
# psnr = 37.90673065,  bpp = 0.08916987, ms-ssim =0.98437384

# %%
# !python experiment.py -i UVG_frames/Bosphorus/ -m checkpoints/videocompressor16-msssim.pkl -g 12
# Out:
# Average
# psnr = 37.45803795,  bpp = 0.06018201, ms-ssim =0.98212160

# %%
# !python experiment.py -i UVG_frames/Bosphorus/ -m checkpoints/videocompressor8-msssim.pkl -g 12
# Out:
# Average
# psnr = 36.72775764,  bpp = 0.03713398, ms-ssim =0.97828609

# %%
# !python experiment.py -i UVG_frames/Honeybee/ -m checkpoints/videocompressor8192.pkl -g 12
# Out:
# Average
# psnr = 38.57379990,  bpp = 0.38525879, ms-ssim =0.98436550

# %%
# !python experiment.py -i UVG_frames/Honeybee/ -m checkpoints/videocompressor4096.pkl -g 12
# Out:
# Average
# psnr = 37.46439209,  bpp = 0.14062879, ms-ssim =0.97941934

# %%
# !python experiment.py -i UVG_frames/Honeybee/ -m checkpoints/videocompressor2048.pkl -g 12
# Out:
# Average
# psnr = 37.12516785,  bpp = 0.07238486, ms-ssim =0.97720898

# %%
# !python experiment.py -i UVG_frames/Honeybee/ -m checkpoints/videocompressor1024.pkl -g 12
# Out:
# Average
# psnr = 37.08030510,  bpp = 0.03968821, ms-ssim =0.97735203

# %%
# !python experiment.py -i UVG_frames/Honeybee/ -m checkpoints/videocompressor512.pkl -g 12
# Out:
# Average
# psnr = 36.96519051,  bpp = 0.02536480, ms-ssim =0.97635373

# %%
# !python experiment.py -i UVG_frames/Honeybee/ -m checkpoints/videocompressor256.pkl -g 12
# Out:
# Average
# psnr = 36.71224632,  bpp = 0.01748314, ms-ssim =0.97433472

# %%
# !python experiment.py -i UVG_frames/Honeybee/ -m checkpoints/videocompressor128.pkl -g 12
# Out:
# Average
# psnr = 36.46290245,  bpp = 0.01210444, ms-ssim =0.97346674

# %%
# !python experiment.py -i UVG_frames/Honeybee/ -m checkpoints/videocompressor256-msssim.pkl -g 12
# Out:
# Average
# psnr = 38.18470917,  bpp = 0.42368146, ms-ssim =0.98730161

# %%
# !python experiment.py -i UVG_frames/Honeybee/ -m checkpoints/videocompressor128-msssim.pkl -g 12
# Out:
# Average
# psnr = 37.20683098,  bpp = 0.18582550, ms-ssim =0.98547489

# %%
# !python experiment.py -i UVG_frames/Honeybee/ -m checkpoints/videocompressor64-msssim.pkl -g 12
# Out:
# Average
# psnr = 37.24843140,  bpp = 0.12082256, ms-ssim =0.98506632

# %%
# !python experiment.py -i UVG_frames/Honeybee/ -m checkpoints/videocompressor32-msssim.pkl -g 12
# Out:
# Average
# psnr = 37.09528580,  bpp = 0.08220670, ms-ssim =0.97948934

# %%
# !python experiment.py -i UVG_frames/Honeybee/ -m checkpoints/videocompressor16-msssim.pkl -g 12
# Out:
# Average
# psnr = 36.82812271,  bpp = 0.04418155, ms-ssim =0.97819133

# %%
# !python experiment.py -i UVG_frames/Honeybee/ -m checkpoints/videocompressor8-msssim.pkl -g 12
# Out:
# Average
# psnr = 36.49411774,  bpp = 0.02280761, ms-ssim =0.97694859

# %%
# !python experiment.py -i UVG_frames/Jockey/ -m checkpoints/videocompressor8192.pkl -g 12
# Out:
# Average
# psnr = 38.05876198,  bpp = 0.77483957, ms-ssim =0.97729586

# %%
# !python experiment.py -i UVG_frames/Jockey/ -m checkpoints/videocompressor4096.pkl -g 12
# Out:
# Average
# psnr = 36.67928925,  bpp = 0.38494080, ms-ssim =0.96533812

# %%
# !python experiment.py -i UVG_frames/Jockey/ -m checkpoints/videocompressor2048.pkl -g 12
# Out:
# Average
# psnr = 35.30267258,  bpp = 0.25473744, ms-ssim =0.95222400

# %%
# !python experiment.py -i UVG_frames/Jockey/ -m checkpoints/videocompressor1024.pkl -g 12
# Out:
# Average
# psnr = 34.07254829,  bpp = 0.17865973, ms-ssim =0.93648348

# %%
# !python experiment.py -i UVG_frames/Jockey/ -m checkpoints/videocompressor512.pkl -g 12
# Out:
# Average
# psnr = 32.77841263,  bpp = 0.12132276, ms-ssim =0.91776153

# %%
# !python experiment.py -i UVG_frames/Jockey/ -m checkpoints/videocompressor256.pkl -g 12
# Out:
# Average
# psnr = 31.44542522,  bpp = 0.08394257, ms-ssim =0.89519908

# %%
# !python experiment.py -i UVG_frames/Jockey/ -m checkpoints/videocompressor128.pkl -g 12
# Out:
# Average
# psnr = 30.03409443,  bpp = 0.05352427, ms-ssim =0.86736804

# %%
# !python experiment.py -i UVG_frames/Jockey/ -m checkpoints/videocompressor256-msssim.pkl -g 12
# Out:
# Average
# psnr = 35.71367455,  bpp = 0.55375232, ms-ssim =0.98073444

# %%
# !python experiment.py -i UVG_frames/Jockey/ -m checkpoints/videocompressor128-msssim.pkl -g 12
# Out:
# Average
# psnr = 32.60431252,  bpp = 0.30505755, ms-ssim =0.96569713

# %%
# !python experiment.py -i UVG_frames/Jockey/ -m checkpoints/videocompressor64-msssim.pkl -g 12
# Out:
# Average
# psnr = 32.43094864,  bpp = 0.22799109, ms-ssim =0.96158432

# %%
# !python experiment.py -i UVG_frames/Jockey/ -m checkpoints/videocompressor32-msssim.pkl -g 12
# Out:
# Average
# psnr = 32.27528114,  bpp = 0.18949946, ms-ssim =0.95507209

# %%
# !python experiment.py -i UVG_frames/Jockey/ -m checkpoints/videocompressor16-msssim.pkl -g 12
# Out:
# Average
# psnr = 31.99770718,  bpp = 0.14945518, ms-ssim =0.94996637

# %%
# !python experiment.py -i UVG_frames/Jockey/ -m checkpoints/videocompressor8-msssim.pkl -g 12
# Out:
# Average
# psnr = 31.36412373,  bpp = 0.10073775, ms-ssim =0.93859115

# %%
# !python experiment.py -i UVG_frames/ReadySetGo/ -m checkpoints/videocompressor8192.pkl -g 12
# Out:
# Average
# psnr = 38.22450829,  bpp = 0.51780391, ms-ssim =0.99041321

# %%
# !python experiment.py -i UVG_frames/ReadySetGo/ -m checkpoints/videocompressor4096.pkl -g 12
# Out:
# Average
# psnr = 36.63932037,  bpp = 0.28979515, ms-ssim =0.98703303

# %%
# !python experiment.py -i UVG_frames/ReadySetGo/ -m checkpoints/videocompressor2048.pkl -g 12
# Out:
# Average
# psnr = 35.16942902,  bpp = 0.17991744, ms-ssim =0.98375415

# %%
# !python experiment.py -i UVG_frames/ReadySetGo/ -m checkpoints/videocompressor1024.pkl -g 12
# Out:
# Average
# psnr = 34.11971970,  bpp = 0.10937692, ms-ssim =0.98072919

# %%
# !python experiment.py -i UVG_frames/ReadySetGo/ -m checkpoints/videocompressor512.pkl -g 12
# Out:
# Average
# psnr = 33.18921127,  bpp = 0.06116599, ms-ssim =0.97809070

# %%
# !python experiment.py -i UVG_frames/ReadySetGo/ -m checkpoints/videocompressor256.pkl -g 12
# Out:
# Average
# psnr = 32.17119846,  bpp = 0.03490572, ms-ssim =0.97504010

# %%
# !python experiment.py -i UVG_frames/ReadySetGo/ -m checkpoints/videocompressor128.pkl -g 12
# Out:
# Average
# psnr = 31.39764099,  bpp = 0.02001622, ms-ssim =0.97206054

# %%
# !python experiment.py -i UVG_frames/ReadySetGo/ -m checkpoints/videocompressor256-msssim.pkl -g 12
# Out:
# Average
# psnr = 35.01213264,  bpp = 0.42195312, ms-ssim =0.99107630

# %%
# !python experiment.py -i UVG_frames/ReadySetGo/ -m checkpoints/videocompressor128-msssim.pkl -g 12
# Out:
# Average
# psnr = 32.48237038,  bpp = 0.19232754, ms-ssim =0.98879863

# %%
# !python experiment.py -i UVG_frames/ReadySetGo/ -m checkpoints/videocompressor64-msssim.pkl -g 12
# Out:
# Average
# psnr = 32.25160236,  bpp = 0.13138981, ms-ssim =0.98632313

# %%
# !python experiment.py -i UVG_frames/ReadySetGo/ -m checkpoints/videocompressor32-msssim.pkl -g 12
# Out:
# Average
# psnr = 32.04637070,  bpp = 0.09562398, ms-ssim =0.98149331

# %%
# !python experiment.py -i UVG_frames/ReadySetGo/ -m checkpoints/videocompressor16-msssim.pkl -g 12
# Out:
# Average
# psnr = 31.71131268,  bpp = 0.06344942, ms-ssim =0.97984404

# %%
# !python experiment.py -i UVG_frames/ReadySetGo/ -m checkpoints/videocompressor8-msssim.pkl -g 12
# Out:
# Average
# psnr = 31.22166100,  bpp = 0.03844740, ms-ssim =0.97765014

# %%
# !python experiment.py -i UVG_frames/ShakeNDry/ -m checkpoints/videocompressor8192.pkl -g 12
# Out:
# Average
# psnr = 37.85708923,  bpp = 0.73242318, ms-ssim =0.98294690

# %%
# !python experiment.py -i UVG_frames/ShakeNDry/ -m checkpoints/videocompressor4096.pkl -g 12
# Out:
# Average
# psnr = 36.39126015,  bpp = 0.41661428, ms-ssim =0.97473075

# %%
# !python experiment.py -i UVG_frames/ShakeNDry/ -m checkpoints/videocompressor2048.pkl -g 12
# Out:
# Average
# psnr = 35.18617516,  bpp = 0.27386927, ms-ssim =0.96551713

# %%
# !python experiment.py -i UVG_frames/ShakeNDry/ -m checkpoints/videocompressor1024.pkl -g 12
# Out:
# Average
# psnr = 34.09551239,  bpp = 0.17848396, ms-ssim =0.95452462

# %%
# !python experiment.py -i UVG_frames/ShakeNDry/ -m checkpoints/videocompressor512.pkl -g 12
# Out:
# Average
# psnr = 33.00460052,  bpp = 0.10819120, ms-ssim =0.93993631

# %%
# !python experiment.py -i UVG_frames/ShakeNDry/ -m checkpoints/videocompressor256.pkl -g 12
# Out:
# Average
# psnr = 31.95506897,  bpp = 0.06295400, ms-ssim =0.92277524

# %%
# !python experiment.py -i UVG_frames/ShakeNDry/ -m checkpoints/videocompressor128.pkl -g 12
# Out:
# Average
# psnr = 30.99495068,  bpp = 0.03168658, ms-ssim =0.90224642

# %%
# !python experiment.py -i UVG_frames/ShakeNDry/ -m checkpoints/videocompressor256-msssim.pkl -g 12
# Out:
# Average
# psnr = 35.55844460,  bpp = 0.54529573, ms-ssim =0.98156088

# %%
# !python experiment.py -i UVG_frames/ShakeNDry/ -m checkpoints/videocompressor128-msssim.pkl -g 12
# Out:
# Average
# psnr = 33.02413788,  bpp = 0.28374680, ms-ssim =0.96825508

# %%
# !python experiment.py -i UVG_frames/ShakeNDry/ -m checkpoints/videocompressor64-msssim.pkl -g 12
# Out:
# Average
# psnr = 32.70775566,  bpp = 0.20239997, ms-ssim =0.96174572

# %%
# !python experiment.py -i UVG_frames/ShakeNDry/ -m checkpoints/videocompressor32-msssim.pkl -g 12
# Out:
# Average
# psnr = 32.55390778,  bpp = 0.16222305, ms-ssim =0.95353510

# %%
# !python experiment.py -i UVG_frames/ShakeNDry/ -m checkpoints/videocompressor16-msssim.pkl -g 12
# Out:
# Average
# psnr = 32.28507919,  bpp = 0.12174359, ms-ssim =0.94919015

# %%
# !python experiment.py -i UVG_frames/ShakeNDry/ -m checkpoints/videocompressor8-msssim.pkl -g 12
# Out:
# Average
# psnr = 31.79484386,  bpp = 0.07839180, ms-ssim =0.93997406

# %%
# !python experiment.py -i UVG_frames/YachtRide/ -m checkpoints/videocompressor8192.pkl -g 12
# Out:
# Average
# psnr = 39.60374413,  bpp = 0.53374339, ms-ssim =0.98828121

# %%
# !python experiment.py -i UVG_frames/YachtRide/ -m checkpoints/videocompressor4096.pkl -g 12
# Out:
# Average
# psnr = 38.22384644,  bpp = 0.31002215, ms-ssim =0.98421679

# %%
# !python experiment.py -i UVG_frames/YachtRide/ -m checkpoints/videocompressor2048.pkl -g 12
# Out:
# Average
# psnr = 36.59594650,  bpp = 0.21028870, ms-ssim =0.97812722

# %%
# !python experiment.py -i UVG_frames/YachtRide/ -m checkpoints/videocompressor1024.pkl -g 12
# Out:
# Average
# psnr = 35.13597183,  bpp = 0.14175448, ms-ssim =0.97030657

# %%
# !python experiment.py -i UVG_frames/YachtRide/ -m checkpoints/videocompressor512.pkl -g 12
# Out:
# Average
# psnr = 33.57305832,  bpp = 0.08908636, ms-ssim =0.96006603

# %%
# !python experiment.py -i UVG_frames/YachtRide/ -m checkpoints/videocompressor256.pkl -g 12
# Out:
# Average
# psnr = 32.14292164,  bpp = 0.05647058, ms-ssim =0.94663656

# %%
# !python experiment.py -i UVG_frames/YachtRide/ -m checkpoints/videocompressor128.pkl -g 12
# Out:
# Average
# psnr = 30.75821018,  bpp = 0.03401359, ms-ssim =0.92732797

# %%
# !python experiment.py -i UVG_frames/YachtRide/ -m checkpoints/videocompressor256-msssim.pkl -g 12
# Out:
# Average
# psnr = 35.69905128,  bpp = 0.44379521, ms-ssim =0.99019325

# %%
# !python experiment.py -i UVG_frames/YachtRide/ -m checkpoints/videocompressor128-msssim.pkl -g 12
# Out:
# Average
# psnr = 33.08080139,  bpp = 0.22659543, ms-ssim =0.98467095

# %%
# !python experiment.py -i UVG_frames/YachtRide/ -m checkpoints/videocompressor64-msssim.pkl -g 12
# Out:
# Average
# psnr = 32.76015911,  bpp = 0.16543248, ms-ssim =0.98113965

# %%
# !python experiment.py -i UVG_frames/YachtRide/ -m checkpoints/videocompressor32-msssim.pkl -g 12
# Out:
# Average
# psnr = 32.66030178,  bpp = 0.12940596, ms-ssim =0.97789274

# %%
# !python experiment.py -i UVG_frames/YachtRide/ -m checkpoints/videocompressor16-msssim.pkl -g 12
# Out:
# Average
# psnr = 32.38676910,  bpp = 0.09552606, ms-ssim =0.97442439

# %%
# !python experiment.py -i UVG_frames/YachtRide/ -m checkpoints/videocompressor8-msssim.pkl -g 12
# Out:
# Average
# psnr = 31.85580750,  bpp = 0.06501627, ms-ssim =0.96822974

# %% [markdown]
# ## PSNR and MSSSIM for x264 and x265

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Beauty/ -o UVG_compressed_PNGS/Beauty/H264_15/
# Out:
# Average
# psnr = 35.64666939, ms-ssim =0.94092890

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Beauty/ -o UVG_compressed_PNGS/Beauty/H264_19/
# Out:
# Average
# psnr = 34.07218790, ms-ssim =0.90624900

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Beauty/ -o UVG_compressed_PNGS/Beauty/H264_23/
# Out:
# Average
# psnr = 33.25546265, ms-ssim =0.88756210

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Beauty/ -o UVG_compressed_PNGS/Beauty/H264_27/
# Out:
# Average
# psnr = 32.61014907, ms-ssim =0.87682311

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Beauty/ -o UVG_compressed_PNGS/Beauty/H265_15/
# Out:
# Average
# psnr = 35.82262929, ms-ssim =0.94191081

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Beauty/ -o UVG_compressed_PNGS/Beauty/H265_19/
# Out:
# Average
# psnr = 34.33214076, ms-ssim =0.91094374

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Beauty/ -o UVG_compressed_PNGS/Beauty/H265_23/
# Out:
# Average
# psnr = 33.63473129, ms-ssim =0.89464238

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Beauty/ -o UVG_compressed_PNGS/Beauty/H265_27/
# Out:
# Average
# psnr = 33.09304094, ms-ssim =0.88551154

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Bosphorus/ -o UVG_compressed_PNGS/Bosphorus/H264_15/
# Out:
# Average
# psnr = 39.51235485, ms-ssim =0.98404763

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Bosphorus/ -o UVG_compressed_PNGS/Bosphorus/H264_19/
# Out:
# Average
# psnr = 37.98942773, ms-ssim =0.97838038

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Bosphorus/ -o UVG_compressed_PNGS/Bosphorus/H264_23/
# Out:
# Average
# psnr = 36.34257857, ms-ssim =0.96909908

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Bosphorus/ -o UVG_compressed_PNGS/Bosphorus/H264_27/
# Out:
# Average
# psnr = 34.54932372, ms-ssim =0.95467907

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Bosphorus/ -o UVG_compressed_PNGS/Bosphorus/H265_15/
# Out:
# Average
# psnr = 40.30257829, ms-ssim =0.98557405

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Bosphorus/ -o UVG_compressed_PNGS/Bosphorus/H265_19/
# Out:
# Average
# psnr = 38.85023880, ms-ssim =0.98076523

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Bosphorus/ -o UVG_compressed_PNGS/Bosphorus/H265_23/
# Out:
# Average
# psnr = 37.39326413, ms-ssim =0.97422074

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Bosphorus/ -o UVG_compressed_PNGS/Bosphorus/H265_27/
# Out:
# Average
# psnr = 35.81871239, ms-ssim =0.96445833

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Honeybee/ -o UVG_compressed_PNGS/HoneyBee/H264_15/
# Out:
# Average
# psnr = 37.58037710, ms-ssim =0.97937932

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Honeybee/ -o UVG_compressed_PNGS/HoneyBee/H264_19/
# Out:
# Average
# psnr = 36.57612435, ms-ssim =0.97520872

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Honeybee/ -o UVG_compressed_PNGS/HoneyBee/H264_23/
# Out:
# Average
# psnr = 35.59379292, ms-ssim =0.97145093

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Honeybee/ -o UVG_compressed_PNGS/HoneyBee/H264_27/
# Out:
# Average
# psnr = 34.32509851, ms-ssim =0.96507170

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Honeybee/ -o UVG_compressed_PNGS/HoneyBee/H265_15/
# Out:
# Average
# psnr = 38.30149953, ms-ssim =0.98196933

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Honeybee/ -o UVG_compressed_PNGS/HoneyBee/H265_19/
# Out:
# Average
# psnr = 37.47074159, ms-ssim =0.97877359

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Honeybee/ -o UVG_compressed_PNGS/HoneyBee/H265_23/
# Out:
# Average
# psnr = 36.55239121, ms-ssim =0.97520958

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Honeybee/ -o UVG_compressed_PNGS/HoneyBee/H265_27/
# Out:
# Average
# psnr = 35.41893196, ms-ssim =0.97015584

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Jockey/ -o UVG_compressed_PNGS/Jockey/H264_15/
# Out:
# Average
# psnr = 38.24679931, ms-ssim =0.97618489

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Jockey/ -o UVG_compressed_PNGS/Jockey/H264_19/
# Out:
# Average
# psnr = 37.11853186, ms-ssim =0.97085219

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Jockey/ -o UVG_compressed_PNGS/Jockey/H264_23/
# Out:
# Average
# psnr = 35.89247592, ms-ssim =0.96326208

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Jockey/ -o UVG_compressed_PNGS/Jockey/H264_27/
# Out:
# Average
# psnr = 34.37304735, ms-ssim =0.95101272

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Jockey/ -o UVG_compressed_PNGS/Jockey/H265_15/
# Out:
# Average
# psnr = 39.02133004, ms-ssim =0.97879797

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Jockey/ -o UVG_compressed_PNGS/Jockey/H265_19/
# Out:
# Average
# psnr = 37.99015919, ms-ssim =0.97374323

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Jockey/ -o UVG_compressed_PNGS/Jockey/H265_23/
# Out:
# Average
# psnr = 36.93727255, ms-ssim =0.96825324

# %%
# !python psnr_msssim_calc.py -i UVG_frames/Jockey/ -o UVG_compressed_PNGS/Jockey/H265_27/
# Out:
# Average
# psnr = 35.71056986, ms-ssim =0.96062632

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ReadySetGo/ -o UVG_compressed_PNGS/ReadySetGo/H264_15/
# Out:
# Average
# psnr = 36.81915363, ms-ssim =0.98603168

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ReadySetGo/ -o UVG_compressed_PNGS/ReadySetGo/H264_19/
# Out:
# Average
# psnr = 35.21874412, ms-ssim =0.98202144

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ReadySetGo/ -o UVG_compressed_PNGS/ReadySetGo/H264_23/
# Out:
# Average
# psnr = 33.43581827, ms-ssim =0.97600117

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ReadySetGo/ -o UVG_compressed_PNGS/ReadySetGo/H264_27/
# Out:
# Average
# psnr = 31.46485670, ms-ssim =0.96573867

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ReadySetGo/ -o UVG_compressed_PNGS/ReadySetGo/H265_15/
# Out:
# Average
# psnr = 37.89769157, ms-ssim =0.98747407

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ReadySetGo/ -o UVG_compressed_PNGS/ReadySetGo/H265_19/
# Out:
# Average
# psnr = 36.34697564, ms-ssim =0.98405227

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ReadySetGo/ -o UVG_compressed_PNGS/ReadySetGo/H265_23/
# Out:
# Average
# psnr = 34.64201641, ms-ssim =0.97909154

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ReadySetGo/ -o UVG_compressed_PNGS/ReadySetGo/H265_27/
# Out:
# Average
# psnr = 32.81489086, ms-ssim =0.97170603

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ShakeNDry/ -o UVG_compressed_PNGS/ShakeNDry/H264_15/
# Out:
# Average
# psnr = 35.79726378, ms-ssim =0.96920675

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ShakeNDry/ -o UVG_compressed_PNGS/ShakeNDry/H264_19/
# Out:
# Average
# psnr = 34.29887136, ms-ssim =0.95632382

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ShakeNDry/ -o UVG_compressed_PNGS/ShakeNDry/H264_23/
# Out:
# Average
# psnr = 32.78092464, ms-ssim =0.93675538

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ShakeNDry/ -o UVG_compressed_PNGS/ShakeNDry/H264_27/
# Out:
# Average
# psnr = 31.17678046, ms-ssim =0.90599839

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ShakeNDry/ -o UVG_compressed_PNGS/ShakeNDry/H265_15/
# Out:
# Average
# psnr = 36.56069946, ms-ssim =0.97324571

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ShakeNDry/ -o UVG_compressed_PNGS/ShakeNDry/H265_19/
# Out:
# Average
# psnr = 35.10484536, ms-ssim =0.96265317

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ShakeNDry/ -o UVG_compressed_PNGS/ShakeNDry/H265_23/
# Out:
# Average
# psnr = 33.52067995, ms-ssim =0.94611903

# %%
# !python psnr_msssim_calc.py -i UVG_frames/ShakeNDry/ -o UVG_compressed_PNGS/ShakeNDry/H265_27/
# Out:
# Average
# psnr = 31.87607114, ms-ssim =0.92124215

# %%
# !python psnr_msssim_calc.py -i UVG_frames/YachtRide/ -o UVG_compressed_PNGS/YachtRide/H264_15/
# Out:
# Average
# psnr = 38.15114784, ms-ssim =0.98335522

# %%
# !python psnr_msssim_calc.py -i UVG_frames/YachtRide/ -o UVG_compressed_PNGS/YachtRide/H264_19/
# Out:
# Average
# psnr = 36.42190679, ms-ssim =0.97737411

# %%
# !python psnr_msssim_calc.py -i UVG_frames/YachtRide/ -o UVG_compressed_PNGS/YachtRide/H264_23/
# Out:
# Average
# psnr = 34.51881218, ms-ssim =0.96738104

# %%
# !python psnr_msssim_calc.py -i UVG_frames/YachtRide/ -o UVG_compressed_PNGS/YachtRide/H264_27/
# Out:
# Average
# psnr = 32.43554838, ms-ssim =0.94983368

# %%
# !python psnr_msssim_calc.py -i UVG_frames/YachtRide/ -o UVG_compressed_PNGS/YachtRide/H265_15/
# Out:
# Average
# psnr = 39.18990564, ms-ssim =0.98548237

# %%
# !python psnr_msssim_calc.py -i UVG_frames/YachtRide/ -o UVG_compressed_PNGS/YachtRide/H265_19/
# Out:
# Average
# psnr = 37.47304789, ms-ssim =0.98060186

# %%
# !python psnr_msssim_calc.py -i UVG_frames/YachtRide/ -o UVG_compressed_PNGS/YachtRide/H265_23/
# Out:
# Average
# psnr = 35.66584110, ms-ssim =0.97336997

# %%
# !python psnr_msssim_calc.py -i UVG_frames/YachtRide/ -o UVG_compressed_PNGS/YachtRide/H265_27/
# Out:
# Average
# psnr = 33.73075120, ms-ssim =0.96205495
